# %% [markdown]
# ## Transform ##

# %% [markdown]
# In the previous step I carried out a quality check on the data and found there were several issues that need to be addressed.
# - Remove unwanted columns
# - Duplicated rows
# - Null values
# - Data type for the date column
# - the data in salary column uses different scales.
# - some job listing dont contain values for salary

# %%
import pandas as pd
df_raw = pd.read_csv('reed_api_data.csv', index_col=0)
df_raw.iloc[0]
# Out:
# jobId                                                           54047135
# employerId                                                        409522
# employerName                                                         WTW
# employerProfileId                                                    NaN
# employerProfileName                                                  NaN
# jobTitle                                           Senior Data Scientist
# locationName                                                      London
# minimumSalary                                                        NaN
# maximumSalary                                                        NaN
# currency                                                             NaN
# expirationDate                                                30/12/2024
# date                                                          18/11/2024
# jobDescription         We are looking for a Data Scientist, with expe...
# applications                                                          14
# jobUrl                 https://www.reed.co.uk/jobs/senior-data-scient...
# city                                                              London
# Name: 0, dtype: object

# %% [markdown]
# Firstly I will drop the employerProfileId and employerProfileName columns as these dont contain any useful data, I will also remove the locationName column as this contains a mixture of postcodes and city names which will be difficult to analise instead I will use the city column which was created when the data was extracted and contains only city names.

# %%
df_raw = df_raw.drop(columns=["employerProfileId",	"employerProfileName", "locationName"])
df_raw.iloc[0]
# Out:
# jobId                                                      54047135
# employerId                                                   409522
# employerName                                                    WTW
# jobTitle                                      Senior Data Scientist
# minimumSalary                                                   NaN
# maximumSalary                                                   NaN
# currency                                                        NaN
# expirationDate                                           30/12/2024
# date                                                     18/11/2024
# jobDescription    We are looking for a Data Scientist, with expe...
# applications                                                     14
# jobUrl            https://www.reed.co.uk/jobs/senior-data-scient...
# city                                                         London
# Name: 0, dtype: object

# %% [markdown]
# I will now convert the date column to datetime format this will help with sorting and analysing the data later on

# %%
df_raw.dtypes
# Out:
# jobId               int64
# employerId          int64
# employerName       object
# jobTitle           object
# minimumSalary     float64
# maximumSalary     float64
# currency           object
# expirationDate     object
# date               object
# jobDescription     object
# applications        int64
# jobUrl             object
# city               object
# dtype: object

# %%
print(df_raw['date'].max())
df_raw['date'].dtype
# Out:
# 31/10/2024
# dtype('O')

# %%
df_raw['date'] = pd.to_datetime(df_raw['date'], dayfirst=True)
df_raw.dtypes
# Out:
# jobId                      int64
# employerId                 int64
# employerName              object
# jobTitle                  object
# minimumSalary            float64
# maximumSalary            float64
# currency                  object
# expirationDate            object
# date              datetime64[ns]
# jobDescription            object
# applications               int64
# jobUrl                    object
# city                      object
# dtype: object

# %%
df_raw.head()
# Out:
#       jobId  employerId            employerName               jobTitle  \
# 0  54047135      409522                     WTW  Senior Data Scientist
# 1  53989684      501640                Vitality    Lead Data Scientist
# 2  54032986      543104               Jobheron          Data Scientist
# 3  53929241      472032  Proactive Appointments         Data Scientist
# 4  54054640      524441    INTEC SELECT LIMITED         Data Scientist
#
#    minimumSalary  maximumSalary currency expirationDate       date  \
# 0            NaN            NaN      NaN     30/12/2024 2024-11-18
# 1            NaN            NaN      NaN     06/12/2024 2024-11-08
# 2        40000.0        55000.0      GBP     27/12/2024 2024-11-15
# 3            NaN            NaN      NaN     10/12/2024 2024-10-29
# 4          450.0          500.0      GBP     01/01/2025 2024-11-20
#
#                                       jobDescription  applications  \
# 0  We are looking for a Data Scientist, with expe...            14
# 1  About The Role Team – &nbsp;Data Science Worki...            29
# 2  A Data Scientist, who must have a PhD&nbsp; qu...            55
# 3  Data Scientist -&nbsp; Remote Working Data Sci...           245
# 4  Data Scientist – 450-500pd PAYE – 7 month cont...            27
#
#                                               jobUrl    city
# 0  https://www.reed.co.uk/jobs/senior-data-scient...  London
# 1  https://www.reed.co.uk/jobs/lead-data-scientis...  London
# 2  https://www.reed.co.uk/jobs/data-scientist/540...  London
# 3  https://www.reed.co.uk/jobs/data-scientist/539...  London
# 4  https://www.reed.co.uk/jobs/data-scientist/540...  London

# %%
print(df_raw['date'].max())
print(df_raw['date'].min())
# Out:
# 2024-11-21 00:00:00
# 2020-11-03 00:00:00

# %%
df_raw[df_raw['date'] == df_raw['date'].min()]
# Out:
#          jobId  employerId                          employerName  \
# 3217  41308637        1990  Gregory Martin International Limited
#
#              jobTitle  minimumSalary  maximumSalary currency expirationDate  \
# 3217  Cost Consultant        35000.0        65000.0      GBP     29/11/2024
#
#            date                                     jobDescription  \
# 3217 2020-11-03  Cost Consultant / Cost Engineer Our client is ...
#
#       applications                                             jobUrl  \
# 3217            60  https://www.reed.co.uk/jobs/cost-consultant/41...
#
#              city
# 3217  Southampton

# %% [markdown]
# Now that we have converted the date column to datetime format I will sort the data by date

# %%
df_raw = df_raw.sort_values(by='date', ascending=False,)
df_raw = df_raw.reset_index(drop=True)
df_raw.head(10)
# Out:
#       jobId  employerId                    employerName  \
# 0  54061747      470824                Eames Consulting
# 1  54062533      390934        Jonathan Lee Recruitment
# 2  54061875      121426                 Henderson Scott
# 3  54064282      106910                 SF Recruitment
# 4  54061731       10470         E Personnel Recruitment
# 5  54062999      563926                         Akkodis
# 6  54062921      563926                         Akkodis
# 7  54061255      391063  Opus Recruitment Solutions Ltd
# 8  54064282      106910                 SF Recruitment
# 9  54062843        2030           Futures Manufacturing
#
#                                             jobTitle  minimumSalary  \
# 0  Senior Backend Python Developer - FastAPI / Te...          650.0
# 1                                  Systems Developer        40000.0
# 2                 Software Project Lead  - Low Level        65000.0
# 3                               IT Helpdesk Engineer        28000.0
# 4                                  Systems Engineer         35000.0
# 5                       Mid level .net web developer        40000.0
# 6  Senior C# Developer Microsoft Developer Role L...        50000.0
# 7  AWS DevOps Engineer  AI Integration Project  O...          500.0
# 8                               IT Helpdesk Engineer        28000.0
# 9                        Electronic Systems Engineer        40000.0
#
#    maximumSalary currency expirationDate       date  \
# 0          750.0      GBP     02/01/2025 2024-11-21
# 1        45000.0      GBP     02/01/2025 2024-11-21
# 2        75000.0      GBP     02/01/2025 2024-11-21
# 3        32000.0      GBP     02/01/2025 2024-11-21
# 4        39001.0      GBP     02/01/2025 2024-11-21
# 5        50000.0      GBP     02/01/2025 2024-11-21
# 6        60000.0      GBP     02/01/2025 2024-11-21
# 7          550.0      GBP     02/01/2025 2024-11-21
# 8        32000.0      GBP     02/01/2025 2024-11-21
# 9        60000.0      GBP     02/01/2025 2024-11-21
#
#                                       jobDescription  applications  \
# 0  Senior Backend Python Developer - Python Stack...             0
# 1  **Unlock Your Potential as a Systems Developer...             1
# 2  Software Project Lead Location: Stevenage (Rel...             1
# 3  IT Support Technician Location: Coleshill &amp...             0
# 4  SYSTEMS ENGINEER - BASED IN EPSOM - KT18 5AP -...             0
# 5  C# Software Developer Leicester /Hybrid Role O...             1
# 6  Senior C# Developer Microsoft Developer Role L...             0
# 7  I am currently supporting a FinTech client tha...            21
# 8  IT Support Technician Location: Coleshill &amp...             0
# 9  Do you have experience of systems integration ...             0
#
#                                               jobUrl           city
# 0  https://www.reed.co.uk/jobs/senior-backend-pyt...         London
# 1  https://www.reed.co.uk/jobs/systems-developer/...  Wolverhampton
# 2  https://www.reed.co.uk/jobs/software-project-l...          Luton
# 3  https://www.reed.co.uk/jobs/it-helpdesk-engine...     Birmingham
# 4  https://www.reed.co.uk/jobs/systems-engineer/5...         London
# 5  https://www.reed.co.uk/jobs/mid-level-net-web-...      Leicester
# 6  https://www.reed.co.uk/jobs/senior-c-developer...      Leicester
# 7  https://www.reed.co.uk/jobs/aws-devops-enginee...  Wolverhampton
# 8  https://www.reed.co.uk/jobs/it-helpdesk-engine...  Wolverhampton
# 9  https://www.reed.co.uk/jobs/electronic-systems...      Sheffield

# %% [markdown]
# I will use the duplicated method to check for duplicate rows of data

# %%
duplciated_rows = df_raw[df_raw.duplicated(subset=['jobId'], keep=False)]
duplciated_rows
# Out:
#          jobId  employerId                          employerName  \
# 0     54061747      470824                      Eames Consulting
# 1     54062533      390934              Jonathan Lee Recruitment
# 2     54061875      121426                       Henderson Scott
# 3     54064282      106910                       SF Recruitment
# 5     54062999      563926                               Akkodis
# ...        ...         ...                                   ...
# 9988  50056290      471259                                  MBDA
# 9989  49897629        1990  Gregory Martin International Limited
# 9990  49897629        1990  Gregory Martin International Limited
# 9993  45901240      582327                      ITOL Recruitment
# 9994  45901240      582327                      ITOL Recruitment
#
#                                                jobTitle  minimumSalary  \
# 0     Senior Backend Python Developer - FastAPI / Te...          650.0
# 1                                     Systems Developer        40000.0
# 2                    Software Project Lead  - Low Level        65000.0
# 3                                  IT Helpdesk Engineer        28000.0
# 5                          Mid level .net web developer        40000.0
# ...                                                 ...            ...
# 9988                                Algorithms Engineer            NaN
# 9989                            Senior Analyst Modeller        40000.0
# 9990                            Senior Analyst Modeller        40000.0
# 9993                             Cyber Security Trainee        24000.0
# 9994                             Cyber Security Trainee        24000.0
#
#       maximumSalary currency expirationDate       date  \
# 0             750.0      GBP     02/01/2025 2024-11-21
# 1           45000.0      GBP     02/01/2025 2024-11-21
# 2           75000.0      GBP     02/01/2025 2024-11-21
# 3           32000.0      GBP     02/01/2025 2024-11-21
# 5           50000.0      GBP     02/01/2025 2024-11-21
# ...             ...      ...            ...        ...
# 9988            NaN      NaN     26/11/2024 2023-03-21
# 9989        70000.0      GBP     31/12/2024 2023-02-28
# 9990        70000.0      GBP     31/12/2024 2023-02-28
# 9993        37000.0      GBP     04/12/2024 2022-02-25
# 9994        37000.0      GBP     04/12/2024 2022-02-25
#
#                                          jobDescription  applications  \
# 0     Senior Backend Python Developer - Python Stack...             0
# 1     **Unlock Your Potential as a Systems Developer...             1
# 2     Software Project Lead Location: Stevenage (Rel...             1
# 3     IT Support Technician Location: Coleshill &amp...             0
# 5     C# Software Developer Leicester /Hybrid Role O...             1
# ...                                                 ...           ...
# 9988  Stevenage As an Algorithms Engineer, you will ...            34
# 9989  Senior Analyst - Operational Analysis, Python,...            75
# 9990  Senior Analyst - Operational Analysis, Python,...            75
# 9993  Cyber Security Placement Programme - No Experi...           200
# 9994  Cyber Security Placement Programme - No Experi...           200
#
#                                                  jobUrl           city
# 0     https://www.reed.co.uk/jobs/senior-backend-pyt...         London
# 1     https://www.reed.co.uk/jobs/systems-developer/...  Wolverhampton
# 2     https://www.reed.co.uk/jobs/software-project-l...          Luton
# 3     https://www.reed.co.uk/jobs/it-helpdesk-engine...     Birmingham
# 5     https://www.reed.co.uk/jobs/mid-level-net-web-...      Leicester
# ...                                                 ...            ...
# 9988  https://www.reed.co.uk/jobs/algorithms-enginee...          Luton
# 9989  https://www.reed.co.uk/jobs/senior-analyst-mod...    Southampton
# 9990  https://www.reed.co.uk/jobs/senior-analyst-mod...    Southampton
# 9993  https://www.reed.co.uk/jobs/cyber-security-tra...       Coventry
# 9994  https://www.reed.co.uk/jobs/cyber-security-tra...     Birmingham
#
# [7326 rows x 13 columns]

# %% [markdown]
# We can see that some jobs have been duplicated multiple times

# %%
duplicated_job = df_raw[df_raw['jobId'] == 54032986]
duplicated_job
# Out:
#          jobId  employerId employerName        jobTitle  minimumSalary  \
# 1747  54032986      543104    Jobheron   Data Scientist        40000.0
# 1752  54032986      543104    Jobheron   Data Scientist        40000.0
# 1757  54032986      543104    Jobheron   Data Scientist        40000.0
# 1879  54032986      543104    Jobheron   Data Scientist        40000.0
#
#       maximumSalary currency expirationDate       date  \
# 1747        55000.0      GBP     27/12/2024 2024-11-15
# 1752        55000.0      GBP     27/12/2024 2024-11-15
# 1757        55000.0      GBP     27/12/2024 2024-11-15
# 1879        55000.0      GBP     27/12/2024 2024-11-15
#
#                                          jobDescription  applications  \
# 1747  A Data Scientist, who must have a PhD&nbsp; qu...            55
# 1752  A Data Scientist, who must have a PhD&nbsp; qu...            55
# 1757  A Data Scientist, who must have a PhD&nbsp; qu...            55
# 1879  A Data Scientist, who must have a PhD&nbsp; qu...            55
#
#                                                  jobUrl    city
# 1747  https://www.reed.co.uk/jobs/data-scientist/540...  London
# 1752  https://www.reed.co.uk/jobs/data-scientist/540...  London
# 1757  https://www.reed.co.uk/jobs/data-scientist/540...  London
# 1879  https://www.reed.co.uk/jobs/data-scientist/540...  London

# %% [markdown]
# I will now remove all duplicated jobs from the dataframe

# %%
df = df_raw.drop_duplicates()
print("df length:", len(df_raw))
print("df length:", len(df))
# Out:
# df length: 9997
# df length: 5651

# %% [markdown]
# I can see that some jobs have also been posted multiple times. I will isolate jobs which have the same values for the jobDescription and city columns and delete those also, keeping the entry that has the oldest value for date.

# %%
df = df.sort_values(by=['jobDescription', 'city', 'date'], ascending=[True, True, True])
df = df.drop_duplicates(subset=['jobDescription', 'city'], keep='first')
len(df)
# Out:
# 4915

# %% [markdown]
# The minimumSalary and maximumSalary columns contain a range of different scales, some appear to be yearly salaries while others are daily rates.

# %%
df['maximumSalary'].value_counts()
# Out:
# maximumSalary
# 50000.00    373
# 45000.00    339
# 60000.00    277
# 40000.00    238
# 65000.00    224
#            ...
# 36698.00      1
# 14.40         1
# 11.50         1
# 1200.00       1
# 20.19         1
# Name: count, Length: 341, dtype: int64

# %%
top_salaries = df.sort_values(by='maximumSalary', ascending=False)[['jobId', 'maximumSalary']]
top_salaries.head(10)
# Out:
#          jobId  maximumSalary
# 1624  54044633       960000.0
# 1936  54026785       850000.0
# 2262  54017901       720001.0
# 7627  53869686       500000.0
# 2318  54017540       450000.0
# 2452  54017540       450000.0
# 838   54051404       437879.0
# 6488  53902297       300000.0
# 5337  53935002       250000.0
# 5266  53935002       250000.0

# %%
max_salary = df[df['jobId'] == 54044633]
max_salary
# Out:
#          jobId  employerId employerName                  jobTitle  \
# 1624  54044633      633103      Crimson  Solution Architect - ERP
#
#       minimumSalary  maximumSalary currency expirationDate       date  \
# 1624       840000.0       960000.0      GBP     30/12/2024 2024-11-18
#
#                                          jobDescription  applications  \
# 1624  Solution Architect - ERP Hybrid x2-3 days per ...             7
#
#                                                  jobUrl        city
# 1624  https://www.reed.co.uk/jobs/solution-architect...  Manchester

# %% [markdown]
# When we look at the job with the highest value for maximumSalary we see a value of 960'000 which seems incredibly high, when we investigate further by looking at the jobDescription we see "70-80k" mentioned showing the value in the maximumSalary column has been entered incorrectly.

# %%
highest_paid = df[df['maximumSalary']>100000].sort_values(by='maximumSalary', ascending=False)
len(highest_paid)
# Out:
# 140

# %%
highest_paid.head(20)
# Out:
#          jobId  employerId                            employerName  \
# 1624  54044633      633103                                 Crimson
# 1936  54026785      412685               Nigel Frank International
# 2262  54017901      121426                         Henderson Scott
# 7627  53869686      409660                                  Huxley
# 2318  54017540      472689                  Page Personnel Finance
# 2452  54017540      472689                  Page Personnel Finance
# 838   54051404      520034                               Sanderson
# 6488  53902297      300264                      Client Server Ltd.
# 5266  53935002      634813                               Ortus PSR
# 5337  53935002      634813                               Ortus PSR
# 887   54049040      331522  Harnham - Data & Analytics Recruitment
# 990   54047882      300264                      Client Server Ltd.
# 4800  53948502      331522  Harnham - Data & Analytics Recruitment
# 327   54054811      331522  Harnham - Data & Analytics Recruitment
# 415   54054041      331522  Harnham - Data & Analytics Recruitment
# 516   54054743      653398             Morgan Fraser Group Limited
# 2617  54010940      300264                      Client Server Ltd.
# 2281  54020944      629851            Antony James Recruitment Ltd
# 7923  53851285      396101                        Walsh Employment
# 7871  53851318      396101                        Walsh Employment
#
#                                                jobTitle  minimumSalary  \
# 1624                           Solution Architect - ERP       840000.0
# 1936                             D365 CE Technical Lead        70000.0
# 2262                             Lead Platform Engineer       720000.0
# 7627                    FX Software Engineering Manager       100000.0
# 2318                                FP&A Analyst hybrid        40000.0
# 2452                                FP&A Analyst hybrid        40000.0
# 838                                    Business Analyst        35029.0
# 6488           C++ Developer - Template Metaprogramming       150000.0
# 5266                                  Financial Planner       100000.0
# 5337                                  Financial Planner       100000.0
# 887                     Staff Machine Learning Engineer       185000.0
# 990   Backend Software Engineer C# .Net SQL - Hedge ...       140000.0
# 4800                                    DevOps Engineer       150000.0
# 327                            Principal Data Scientist       120000.0
# 415                     Staff Machine Learning Engineer       135000.0
# 516    Senior Rust Engineer (Backend) - Crypto - Remote       120000.0
# 2617           Senior Java Developer TDD - Technologist       130000.0
# 2281                Vice President of Sales & Marketing        80000.0
# 7923                      Business Development Director       120000.0
# 7871                      Business Development Director       120000.0
#
#       maximumSalary currency expirationDate       date  \
# 1624       960000.0      GBP     30/12/2024 2024-11-18
# 1936       850000.0      GBP     26/12/2024 2024-11-14
# 2262       720001.0      GBP     25/12/2024 2024-11-13
# 7627       500000.0      GBP     28/11/2024 2024-10-17
# 2318       450000.0      GBP     25/12/2024 2024-11-13
# 2452       450000.0      GBP     25/12/2024 2024-11-13
# 838        437879.0      GBP     31/12/2024 2024-11-19
# 6488       300000.0      GBP     21/11/2024 2024-10-24
# 5266       250000.0      GBP     11/12/2024 2024-10-30
# 5337       250000.0      GBP     11/12/2024 2024-10-30
# 887        195000.0      GBP     31/12/2024 2024-11-19
# 990        180000.0      GBP     17/12/2024 2024-11-19
# 4800       180000.0      GBP     13/12/2024 2024-11-01
# 327        180000.0      GBP     01/01/2025 2024-11-20
# 415        175000.0      GBP     18/12/2024 2024-11-20
# 516        160000.0      GBP     01/01/2025 2024-11-20
# 2617       160000.0      GBP     10/12/2024 2024-11-12
# 2281       150000.0      GBP     25/12/2024 2024-11-13
# 7923       150000.0      GBP     26/11/2024 2024-10-15
# 7871       150000.0      GBP     26/11/2024 2024-10-15
#
#                                          jobDescription  applications  \
# 1624  Solution Architect - ERP Hybrid x2-3 days per ...             7
# 1936  Job Description An excellent opportunity to wo...             4
# 2262  Lead Platform Engineer - Hampshire (Hybrid) - ...            10
# 7627  FX Software Engineering Manager C#.NET Finance...            21
# 2318  Fabulous opportunity for someone who has a rea...            11
# 2452  Fabulous opportunity for someone who has a rea...            11
# 838   Business Analyst Who are Diligenta? Diligenta'...            17
# 6488  C Developer / Software Engineer (TMP C 20 / 23...            21
# 5266  Join an Elite Wealth Management Team as a Fina...             3
# 5337  Join an Elite Wealth Management Team as a Fina...             3
# 887   Staff Machine Learning Engineer Salary : 170,0...            12
# 990   Backend Software Engineer / Developer (C# .Net...            19
# 4800  DevOps Engineer Salary: 150,000- 180,000 (Circ...           131
# 327   Staff Machine Learning Engineer Lead a global ...             5
# 415   Staff Machine Learning Engineer London/Remote ...            11
# 516   Senior Software Engineer - Rust (Backend) - Re...             9
# 2617  Senior Backend Software Engineer / Developer (...            25
# 2281  My client is on a mission to revolutionise pro...             5
# 7923  Our client is a purpose driven enterprise AI t...             9
# 7871  Our client is a purpose driven enterprise AI t...            14
#
#                                                  jobUrl            city
# 1624  https://www.reed.co.uk/jobs/solution-architect...      Manchester
# 1936  https://www.reed.co.uk/jobs/d365-ce-technical-...           Leeds
# 2262  https://www.reed.co.uk/jobs/lead-platform-engi...     Southampton
# 7627  https://www.reed.co.uk/jobs/fx-software-engine...          London
# 2318  https://www.reed.co.uk/jobs/fp-a-analyst-hybri...           Derby
# 2452  https://www.reed.co.uk/jobs/fp-a-analyst-hybri...  Stoke-on-Trent
# 838   https://www.reed.co.uk/jobs/business-analyst/5...         Glasgow
# 6488  https://www.reed.co.uk/jobs/c-developer-templa...          London
# 5266  https://www.reed.co.uk/jobs/financial-planner/...           Leeds
# 5337  https://www.reed.co.uk/jobs/financial-planner/...            York
# 887   https://www.reed.co.uk/jobs/staff-machine-lear...      Manchester
# 990   https://www.reed.co.uk/jobs/backend-software-e...          London
# 4800  https://www.reed.co.uk/jobs/devops-engineer/53...          London
# 327   https://www.reed.co.uk/jobs/principal-data-sci...           Leeds
# 415   https://www.reed.co.uk/jobs/staff-machine-lear...          London
# 516   https://www.reed.co.uk/jobs/senior-rust-engine...          London
# 2617  https://www.reed.co.uk/jobs/senior-java-develo...          London
# 2281  https://www.reed.co.uk/jobs/vice-president-of-...       Cambridge
# 7923  https://www.reed.co.uk/jobs/business-developme...        Coventry
# 7871  https://www.reed.co.uk/jobs/business-developme...      Manchester
