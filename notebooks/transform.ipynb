# %% [markdown]
# ## Transform ##

# %% [markdown]
# Now I have the data saved in a pandas dataframe I can now start to transform the data. My first task will be to check for and remove any duplicated data as I suspect some of the searches will return similar job postings.

# %% [markdown]
# I will use the duplicated method to check for duplicate rows of data

# %%
import pandas as pd

# %%
df = pd.read_csv('reed_api_data.csv', index_col=0)
df.iloc[0]
# Out:
# jobId                                                           54047135
# employerId                                                        409522
# employerName                                                         WTW
# employerProfileId                                                    NaN
# employerProfileName                                                  NaN
# jobTitle                                           Senior Data Scientist
# locationName                                                      London
# minimumSalary                                                        NaN
# maximumSalary                                                        NaN
# currency                                                             NaN
# expirationDate                                                30/12/2024
# date                                                          18/11/2024
# jobDescription         We are looking for a Data Scientist, with expe...
# applications                                                          14
# jobUrl                 https://www.reed.co.uk/jobs/senior-data-scient...
# city                                                              London
# Name: 0, dtype: object

# %%
duplciated_rows = df[df.duplicated(subset=['jobId'], keep=False)]
duplciated_rows
# Out:
#          jobId  employerId             employerName  employerProfileId  \
# 2     54032986      543104                Jobheron                 NaN
# 4     54054640      524441     INTEC SELECT LIMITED                NaN
# 6     54056851      400289                 Huntress                NaN
# 8     54064151      429392            Searchability                NaN
# 12    53917216      377106           Robert Walters                NaN
# ...        ...         ...                      ...                ...
# 9991  54049736      300264       Client Server Ltd.                NaN
# 9992  54030987      375315  Spectrum IT Recruitment                NaN
# 9993  53905046      300264       Client Server Ltd.                NaN
# 9994  53987043      300264       Client Server Ltd.                NaN
# 9995  53980000      300264       Client Server Ltd.                NaN
#
#       employerProfileName                                        jobTitle  \
# 2                     NaN                                  Data Scientist
# 4                     NaN                                  Data Scientist
# 6                     NaN                                  Data Scientist
# 8                     NaN                                  Data Scientist
# 12                    NaN                                  Data Scientist
# ...                   ...                                             ...
# 9991                  NaN        Senior C# Developer .Net API AWS - Games
# 9992                  NaN                    Senior PHP Software Engineer
# 9993                  NaN       Senior Software Developer C# .Net API AWS
# 9994                  NaN       Senior Software Developer C# .Net API AWS
# 9995                  NaN  Lead Backend Software Engineer C# .Net API AWS
#
#      locationName  minimumSalary  maximumSalary currency expirationDate  \
# 2          London        40000.0        55000.0      GBP     27/12/2024
# 4         EC3N2EX          450.0          500.0      GBP     01/01/2025
# 6          London           50.0           55.0      GBP     27/11/2024
# 8          London        50000.0        60000.0      GBP     02/01/2025
# 12         London        60000.0        80000.0      GBP     09/12/2024
# ...           ...            ...            ...      ...            ...
# 9991       SR12JR        65000.0        80000.0      GBP     17/12/2024
# 9992       NE11AD        50000.0        60000.0      GBP     29/11/2024
# 9993       SR12JR        70000.0        80000.0      GBP     21/11/2024
# 9994       SR12JR        65000.0        80000.0      GBP     06/12/2024
# 9995       SR12JR        70000.0        80000.0      GBP     05/12/2024
#
#             date                                     jobDescription  \
# 2     15/11/2024  A Data Scientist, who must have a PhD&nbsp; qu...
# 4     20/11/2024  Data Scientist – 450-500pd PAYE – 7 month cont...
# 6     20/11/2024  Data Scientist- London/Remote- 12 Months- 50- ...
# 8     21/11/2024  Data Scientist Opportunity within a Tech4Good ...
# 12    28/10/2024  Our client is in the midst of a crucial growth...
# ...          ...                                                ...
# 9991  19/11/2024  Senior C# Developer / Software Engineer (C# .N...
# 9992  15/11/2024  We're looking for a dynamic Senior PHP Softwar...
# 9993  24/10/2024  Senior Software Developer / Engineer (C# .Net ...
# 9994  08/11/2024  Senior Software Developer / Engineer (C# .Net ...
# 9995  07/11/2024  Lead Backend Software Engineer / Developer (C#...
#
#       applications                                             jobUrl  \
# 2               55  https://www.reed.co.uk/jobs/data-scientist/540...
# 4               27  https://www.reed.co.uk/jobs/data-scientist/540...
# 6               31  https://www.reed.co.uk/jobs/data-scientist/540...
# 8                1  https://www.reed.co.uk/jobs/data-scientist/540...
# 12             159  https://www.reed.co.uk/jobs/data-scientist/539...
# ...            ...                                                ...
# 9991             8  https://www.reed.co.uk/jobs/senior-c-developer...
# 9992            19  https://www.reed.co.uk/jobs/senior-php-softwar...
# 9993            18  https://www.reed.co.uk/jobs/senior-software-de...
# 9994            12  https://www.reed.co.uk/jobs/senior-software-de...
# 9995             9  https://www.reed.co.uk/jobs/lead-backend-softw...
#
#            city
# 2        London
# 4        London
# 6        London
# 8        London
# 12       London
# ...         ...
# 9991  Newcastle
# 9992  Newcastle
# 9993  Newcastle
# 9994  Newcastle
# 9995  Newcastle
#
# [7326 rows x 16 columns]

# %% [markdown]
# We can see that some jobs have been duplicated multiple times

# %%
duplicated_job = df[df['jobId'] == 54032986]
duplicated_job
# Out:
#          jobId  employerId employerName  employerProfileId  \
# 2     54032986      543104    Jobheron                 NaN
# 2193  54032986      543104    Jobheron                 NaN
# 9097  54032986      543104    Jobheron                 NaN
# 9219  54032986      543104    Jobheron                 NaN
#
#       employerProfileName        jobTitle locationName  minimumSalary  \
# 2                     NaN  Data Scientist       London        40000.0
# 2193                  NaN  Data Scientist       London        40000.0
# 9097                  NaN  Data Scientist       London        40000.0
# 9219                  NaN  Data Scientist       London        40000.0
#
#       maximumSalary currency expirationDate        date  \
# 2           55000.0      GBP     27/12/2024  15/11/2024
# 2193        55000.0      GBP     27/12/2024  15/11/2024
# 9097        55000.0      GBP     27/12/2024  15/11/2024
# 9219        55000.0      GBP     27/12/2024  15/11/2024
#
#                                          jobDescription  applications  \
# 2     A Data Scientist, who must have a PhD&nbsp; qu...            55
# 2193  A Data Scientist, who must have a PhD&nbsp; qu...            55
# 9097  A Data Scientist, who must have a PhD&nbsp; qu...            55
# 9219  A Data Scientist, who must have a PhD&nbsp; qu...            55
#
#                                                  jobUrl    city
# 2     https://www.reed.co.uk/jobs/data-scientist/540...  London
# 2193  https://www.reed.co.uk/jobs/data-scientist/540...  London
# 9097  https://www.reed.co.uk/jobs/data-scientist/540...  London
# 9219  https://www.reed.co.uk/jobs/data-scientist/540...  London

# %% [markdown]
# I will now remove all duplicated jobs from the dataframe

# %%
df_no_duplicates = df.drop_duplicates()
print("df length:", len(df))
print("df_no_duplicates length:", len(df_no_duplicates))
# Out:
# df length: 9997
# df_no_duplicates length: 5651

# %% [markdown]
# I will drop the columns I dont need to reduce the amount of data I am working with

# %%
df_no_duplicates = df_no_duplicates.drop(columns=["employerProfileId",	"employerProfileName", "locationName"])
df_no_duplicates.iloc[0]
# Out:
# jobId                                                      54047135
# employerId                                                   409522
# employerName                                                    WTW
# jobTitle                                      Senior Data Scientist
# minimumSalary                                                   NaN
# maximumSalary                                                   NaN
# currency                                                        NaN
# expirationDate                                           30/12/2024
# date                                                     18/11/2024
# jobDescription    We are looking for a Data Scientist, with expe...
# applications                                                     14
# jobUrl            https://www.reed.co.uk/jobs/senior-data-scient...
# city                                                         London
# Name: 0, dtype: object

# %% [markdown]
# In order to be able to analyise the date using the date column the format of the date column needs to be changed from a string to a datetime object

# %%
df_no_duplicates.dtypes
# Out:
# jobId               int64
# employerId          int64
# employerName       object
# jobTitle           object
# minimumSalary     float64
# maximumSalary     float64
# currency           object
# expirationDate     object
# date               object
# jobDescription     object
# applications        int64
# jobUrl             object
# city               object
# dtype: object

# %%
print(df_no_duplicates['date'].max())
df_no_duplicates['date'].dtype
# Out:
# 2024-11-21 00:00:00
# dtype('<M8[ns]')

# %%
df_no_duplicates['date'] = pd.to_datetime(df_no_duplicates['date'], dayfirst=True)
df_no_duplicates.dtypes
# Out:
# jobId                      int64
# employerId                 int64
# employerName              object
# jobTitle                  object
# minimumSalary            float64
# maximumSalary            float64
# currency                  object
# expirationDate            object
# date              datetime64[ns]
# jobDescription            object
# applications               int64
# jobUrl                    object
# city                      object
# dtype: object

# %%
df_no_duplicates[:4]
# Out:
#       jobId  employerId            employerName               jobTitle  \
# 0  54047135      409522                     WTW  Senior Data Scientist
# 1  53989684      501640                Vitality    Lead Data Scientist
# 2  54032986      543104               Jobheron          Data Scientist
# 3  53929241      472032  Proactive Appointments         Data Scientist
#
#    minimumSalary  maximumSalary currency expirationDate       date  \
# 0            NaN            NaN      NaN     30/12/2024 2024-11-18
# 1            NaN            NaN      NaN     06/12/2024 2024-11-08
# 2        40000.0        55000.0      GBP     27/12/2024 2024-11-15
# 3            NaN            NaN      NaN     10/12/2024 2024-10-29
#
#                                       jobDescription  applications  \
# 0  We are looking for a Data Scientist, with expe...            14
# 1  About The Role Team – &nbsp;Data Science Worki...            29
# 2  A Data Scientist, who must have a PhD&nbsp; qu...            55
# 3  Data Scientist -&nbsp; Remote Working Data Sci...           245
#
#                                               jobUrl    city
# 0  https://www.reed.co.uk/jobs/senior-data-scient...  London
# 1  https://www.reed.co.uk/jobs/lead-data-scientis...  London
# 2  https://www.reed.co.uk/jobs/data-scientist/540...  London
# 3  https://www.reed.co.uk/jobs/data-scientist/539...  London

# %%
print(df_no_duplicates['date'].max())
print(df_no_duplicates['date'].min())
# Out:
# 2024-11-21 00:00:00
# 2020-11-03 00:00:00

# %%
df_no_duplicates[df_no_duplicates['date'] == df_no_duplicates['date'].min()]
# Out:
#          jobId  employerId                          employerName  \
# 3217  41308637        1990  Gregory Martin International Limited
#
#              jobTitle  minimumSalary  maximumSalary currency expirationDate  \
# 3217  Cost Consultant        35000.0        65000.0      GBP     29/11/2024
#
#            date                                     jobDescription  \
# 3217 2020-11-03  Cost Consultant / Cost Engineer Our client is ...
#
#       applications                                             jobUrl  \
# 3217            60  https://www.reed.co.uk/jobs/cost-consultant/41...
#
#              city
# 3217  Southampton
